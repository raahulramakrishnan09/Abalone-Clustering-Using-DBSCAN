# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
#Exploratory_data_analysis
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
b=df['Length']
c=df['Height']
d=df['Shell weight']

# %%
#lineplot
plt.plot(b)

# %%
#scatterplot
plt.scatter(b,d)

# %%
#histogrtam
plt.hist(c)
# Out:
# (array([1.023e+03, 3.129e+03, 2.300e+01, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.   , 0.113, 0.226, 0.339, 0.452, 0.565, 0.678, 0.791, 0.904,
#         1.017, 1.13 ]),
#  <BarContainer object of 10 artists>)

# %%
#distributionplot
sns.displot(x=d,data=df)

# %%
#Label_encoding
from sklearn.preprocessing import LabelEncoder
a=LabelEncoder()
df['Sex']=a.fit_transform(df['Sex'])

# %%
from sklearn.cluster import DBSCAN
db=DBSCAN(eps=1,min_samples=240,metric='euclidean')

# %%
model=db.fit(df)

# %%
label=model.labels_
label
# Out:
# array([-1, -1, -1, ...,  2,  4, -1])

# %%
#n_clusters
len(set(label))-(1 if -1 in label else 0)
# Out:
# 5

# %%
y_means=db.fit_predict(df)
y_means
# Out:
# array([-1, -1, -1, ...,  2,  4, -1])

# %%
x=df.iloc[:,[5,6]].values
x
# Out:
# array([[0.2245, 0.101 ],
#        [0.0995, 0.0485],
#        [0.2565, 0.1415],
#        ...,
#        [0.5255, 0.2875],
#        [0.531 , 0.261 ],
#        [0.9455, 0.3765]])

# %%
#Visualizing_the_Clusters
plt.figure(figsize=(7,5))
plt.scatter(x[y_means==0,0],x[y_means==0,1],color='red',label='cluster1',s=30)
plt.scatter(x[y_means==1,0],x[y_means==1,1],color='yellow',label='cluster2',s=30)
plt.scatter(x[y_means==2,0],x[y_means==2,1],color='green',label='cluster3',s=30)
plt.scatter(x[y_means==3,0],x[y_means==3,1],color='blue',label='cluster5',s=30)
plt.scatter(x[y_means==4,0],x[y_means==4,1],color='orange',label='cluster6',s=30)
plt.scatter(x[y_means==5,0],x[y_means==5,1],color='pink',label='cluster7',s=30)
plt.scatter(x[y_means==6,0],x[y_means==6,1],color='indigo',label='cluster8',s=30)
plt.grid(False)
plt.title('Clustering')
plt.xlabel('Diameter')
plt.ylabel('rings')
plt.show()

# %%
df['label']=pd.DataFrame(y_means)

# %%
n=df[df['label']==-1].count()
n
# Out:
# Sex               2823
# Length            2823
# Diameter          2823
# Height            2823
# Whole weight      2823
# Shucked weight    2823
# Viscera weight    2823
# Shell weight      2823
# Rings             2823
# label             2823
# dtype: int64
